# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1hUTAxx_1vMd1W9lLqb_4SvJltSkueXNs?usp=sharing)

# %% [markdown]
# ### **Data Acquisition Overview**
#
# We developed a solution to **download NHL play-by-play data** for both **regular season and playoffs** from **2016-17 to 2023-24**. Here's a summary of how our approach meets the project requirements and adds extra functionality.
#
# ---
#
# ## **Requirements vs. Implementation**
#
# 1. **Download Data for All Seasons (2016-17 to 2023-24):**
#    - Used NHL API to download **regular season** (type `"02"`) and **playoff** games (type `"03"`).
#
# 2. **GAME_ID Formation:**
#    - Generated dynamically from **season year, game type,** and **game number**.
#
# 3. **Efficient Storage:**
#    - Cached data in **Google Drive** to avoid redundant downloads.
#    - Files are **loaded directly from cache** if available.
#
# 4. **Avoid GitHub Large Files:**
#    - Used `.gitignore` to exclude large datasets from GitHub tracking.
#
# 5. **Error Handling:**
#    - Handled **404 errors** and other HTTP issues to ensure uninterrupted downloads.
#
# 6. **Modular Design:**
#    - Organized code into **functions** for easy reuse and maintenance.
#
# ---
#
# ## **Comparison Table**
#
# | **Requirement**                            | **Implemented** | **Details** |
# |--------------------------------------------|----------------|-------------|
# | Download data for regular and playoff games | ✅ | Used correct game types `"02"` and `"03"`. |
# | Form GAME_ID dynamically                    | ✅ | Combined season year, type, and padded game number. |
# | Data from 2016-17 to 2023-24                | ✅ | Automated season-wise download loop. |
# | Save data locally and avoid redundant requests | ✅ | Cached in **Google Drive**. |
# | Handle errors gracefully                    | ✅ | Skipped missing games; caught HTTP exceptions. |
# | Avoid large files in GitHub                 | ✅ | Used `.gitignore` for datasets. |
#
# ---
#
# ## **Extra Features Implemented**
#
# 1. **Persistent Google Drive Caching:**
#    - Ensured data **persists across Colab sessions**.
#
# 2. **Flexible Modular Functions:**
#    - Though not class-based, the solution is **modular and reusable**.
#
# ---

# %% [markdown]
# ## **1. Data Acquisition (25%)**
#
# **To view the Raw downloaded Json Files**
#
# https://drive.google.com/drive/folders/1eze7xj3k3t62rRnIwrO_Vc8I24jIMTQv?usp=sharing

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import os
import requests
import json

# Cache directory inside Google Drive
CACHE_DIR = "/content/drive/MyDrive/NHL_Datas/raw"

def fetch_and_cache_nhl_data(season, game_type, game_number, cache_dir=CACHE_DIR):
    """
    Fetch and cache NHL play-by-play data for a given game.

    Args:
        season (int): Starting year of the NHL season (e.g., 2016 for 2016-17 season).
        game_type (str): '02' for regular season, '03' for playoffs.
        game_number (str): Game number padded to 4 digits (e.g., '0001').
        cache_dir (str): Directory to store cached data.

    Returns:
        dict: JSON data of the play-by-play or None if not found.
    """
    if not os.path.exists(cache_dir):
        os.makedirs(cache_dir)

    game_id = f"{season}{game_type}{game_number}"
    cache_file = os.path.join(cache_dir, f"{game_id}.json")

    if os.path.exists(cache_file):
        print(f"Loading cached data for Game ID {game_id}.")
        with open(cache_file, 'r') as f:
            return json.load(f)

    url = f"https://api-web.nhle.com/v1/gamecenter/{game_id}/play-by-play"
    try:
        print(f"Fetching data for Game ID {game_id}...")
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        save_data_to_file(data, cache_file)
        return data
    except requests.exceptions.HTTPError as err:
        if response.status_code == 404:
            print(f"Game ID {game_id} not found (404). Skipping.")
        else:
            print(f"HTTP Error: {err}")
    except requests.exceptions.RequestException as err:
        print(f"Request Error: {err}")
    return None

def save_data_to_file(data, file_path):
    """
    Save JSON data to a file.

    Args:
        data (dict): JSON data to be saved.
        file_path (str): Path to save the data.
    """
    with open(file_path, 'w') as f:
        json.dump(data, f)
    print(f"Data saved to {file_path}")

def download_season_data(season, game_type="02", max_games=1300):
    """
    Download all play-by-play data for a season.

    Args:
        season (int): The starting year of the season (e.g., 2016 for 2016-17).
        game_type (str): '02' for regular season, '03' for playoffs.
        max_games (int): Maximum games to download (1300 to cover all games).
    """
    for game_number in range(1, max_games + 1):
        game_number_str = str(game_number).zfill(4)
        data = fetch_and_cache_nhl_data(season, game_type, game_number_str)
        if not data:
            break  # Stop if a game ID is not found (end of season)

def download_all_seasons(start_year=2016, end_year=2023):
    """
    Download play-by-play data for all seasons from start_year to end_year.

    Args:
        start_year (int): The first season to download (e.g., 2016).
        end_year (int): The last season to download (e.g., 2023).
    """
    for year in range(start_year, end_year + 1):
        print(f"\nDownloading regular season data for {year}-{year + 1}...")
        download_season_data(year, "02")

        print(f"\nDownloading playoff data for {year}-{year + 1}...")
        download_season_data(year, "03")

# Example: Download all data from 2016-17 to 2023-24
download_all_seasons(2016, 2024)
# Out:
# Streaming output truncated to the last 5000 lines.
# Loading cached data for Game ID 2022020217.
# Loading cached data for Game ID 2022020218.
# Loading cached data for Game ID 2022020219.
# Loading cached data for Game ID 2022020220.
# Loading cached data for Game ID 2022020221.
# Loading cached data for Game ID 2022020222.
# Loading cached data for Game ID 2022020223.
# Loading cached data for Game ID 2022020224.
# Loading cached data for Game ID 2022020225.
# Loading cached data for Game ID 2022020226.
# Loading cached data for Game ID 2022020227.
# Loading cached data for Game ID 2022020228.
# Loading cached data for Game ID 2022020229.
# Loading cached data for Game ID 2022020230.
# Loading cached data for Game ID 2022020231.
# Loading cached data for Game ID 2022020232.
# Loading cached data for Game ID 2022020233.
# Loading cached data for Game ID 2022020234.
# Loading cached data for Game ID 2022020235.
# Loading cached data for Game ID 2022020236.
# Loading cached data for Game ID 2022020237.
# Loading cached data for Game ID 2022020238.
# Loading cached data for Game ID 2022020239.
# Loading cached data for Game ID 2022020240.
# Loading cached data for Game ID 2022020241.
# Loading cached data for Game ID 2022020242.
# Loading cached data for Game ID 2022020243.
# Loading cached data for Game ID 2022020244.
# Loading cached data for Game ID 2022020245.
# Loading cached data for Game ID 2022020246.
# Loading cached data for Game ID 2022020247.
# Loading cached data for Game ID 2022020248.
# Loading cached data for Game ID 2022020249.
# Loading cached data for Game ID 2022020250.
# Loading cached data for Game ID 2022020251.
# Loading cached data for Game ID 2022020252.
# Loading cached data for Game ID 2022020253.
# Loading cached data for Game ID 2022020254.
# Loading cached data for Game ID 2022020255.
# Loading cached data for Game ID 2022020256.
# Loading cached data for Game ID 2022020257.
# Loading cached data for Game ID 2022020258.
# Loading cached data for Game ID 2022020259.
# Loading cached data for Game ID 2022020260.
# Loading cached data for Game ID 2022020261.
# Loading cached data for Game ID 2022020262.
# Loading cached data for Game ID 2022020263.
# Loading cached data for Game ID 2022020264.
# Loading cached data for Game ID 2022020265.
# Loading cached data for Game ID 2022020266.
# Loading cached data for Game ID 2022020267.
# Loading cached data for Game ID 2022020268.
# Loading cached data for Game ID 2022020269.
# Loading cached data for Game ID 2022020270.
# Loading cached data for Game ID 2022020271.
# Loading cached data for Game ID 2022020272.
# Loading cached data for Game ID 2022020273.
# Loading cached data for Game ID 2022020274.
# Loading cached data for Game ID 2022020275.
# Loading cached data for Game ID 2022020276.
# Loading cached data for Game ID 2022020277.
# Loading cached data for Game ID 2022020278.
# Loading cached data for Game ID 2022020279.
# Loading cached data for Game ID 2022020280.
# Loading cached data for Game ID 2022020281.
# Loading cached data for Game ID 2022020282.
# Loading cached data for Game ID 2022020283.
# Loading cached data for Game ID 2022020284.
# Loading cached data for Game ID 2022020285.
# Loading cached data for Game ID 2022020286.
# Loading cached data for Game ID 2022020287.
# Loading cached data for Game ID 2022020288.
# Loading cached data for Game ID 2022020289.
# Loading cached data for Game ID 2022020290.
# Loading cached data for Game ID 2022020291.
# Loading cached data for Game ID 2022020292.
# Loading cached data for Game ID 2022020293.
# Loading cached data for Game ID 2022020294.
# Loading cached data for Game ID 2022020295.
# Loading cached data for Game ID 2022020296.
# Loading cached data for Game ID 2022020297.
# Loading cached data for Game ID 2022020298.
# Loading cached data for Game ID 2022020299.
# Loading cached data for Game ID 2022020300.
# Loading cached data for Game ID 2022020301.
# Loading cached data for Game ID 2022020302.
# Loading cached data for Game ID 2022020303.
# Loading cached data for Game ID 2022020304.
# Loading cached data for Game ID 2022020305.
# Loading cached data for Game ID 2022020306.
# Loading cached data for Game ID 2022020307.
# Loading cached data for Game ID 2022020308.
# Loading cached data for Game ID 2022020309.
# Loading cached data for Game ID 2022020310.
# Loading cached data for Game ID 2022020311.
# Loading cached data for Game ID 2022020312.
# Loading cached data for Game ID 2022020313.
# Loading cached data for Game ID 2022020314.
# Loading cached data for Game ID 2022020315.
# Loading cached data for Game ID 2022020316.
# Loading cached data for Game ID 2022020317.
# Loading cached data for Game ID 2022020318.
# Loading cached data for Game ID 2022020319.
# Loading cached data for Game ID 2022020320.
# Loading cached data for Game ID 2022020321.
# Loading cached data for Game ID 2022020322.
# Loading cached data for Game ID 2022020323.
# Loading cached data for Game ID 2022020324.
# Loading cached data for Game ID 2022020325.
# Loading cached data for Game ID 2022020326.
# Loading cached data for Game ID 2022020327.
# Loading cached data for Game ID 2022020328.
# Loading cached data for Game ID 2022020329.
# Loading cached data for Game ID 2022020330.
# Loading cached data for Game ID 2022020331.
# Loading cached data for Game ID 2022020332.
# Loading cached data for Game ID 2022020333.
# Loading cached data for Game ID 2022020334.
# Loading cached data for Game ID 2022020335.
# Loading cached data for Game ID 2022020336.
# Loading cached data for Game ID 2022020337.
# Loading cached data for Game ID 2022020338.
# Loading cached data for Game ID 2022020339.
# Loading cached data for Game ID 2022020340.
# Loading cached data for Game ID 2022020341.
# Loading cached data for Game ID 2022020342.
# Loading cached data for Game ID 2022020343.
# Loading cached data for Game ID 2022020344.
# Loading cached data for Game ID 2022020345.
# Loading cached data for Game ID 2022020346.
# Loading cached data for Game ID 2022020347.
# Loading cached data for Game ID 2022020348.
# Loading cached data for Game ID 2022020349.
# Loading cached data for Game ID 2022020350.
# Loading cached data for Game ID 2022020351.
# Loading cached data for Game ID 2022020352.
# Loading cached data for Game ID 2022020353.
# Loading cached data for Game ID 2022020354.
# Loading cached data for Game ID 2022020355.
# Loading cached data for Game ID 2022020356.
# Loading cached data for Game ID 2022020357.
# Loading cached data for Game ID 2022020358.
# Loading cached data for Game ID 2022020359.
# Loading cached data for Game ID 2022020360.
# Loading cached data for Game ID 2022020361.
# Loading cached data for Game ID 2022020362.
# Loading cached data for Game ID 2022020363.
# Loading cached data for Game ID 2022020364.
# Loading cached data for Game ID 2022020365.
# Loading cached data for Game ID 2022020366.
# Loading cached data for Game ID 2022020367.
# Loading cached data for Game ID 2022020368.
# Loading cached data for Game ID 2022020369.
# Loading cached data for Game ID 2022020370.
# Loading cached data for Game ID 2022020371.
# Loading cached data for Game ID 2022020372.
# Loading cached data for Game ID 2022020373.
# Loading cached data for Game ID 2022020374.
# Loading cached data for Game ID 2022020375.
# Loading cached data for Game ID 2022020376.
# Loading cached data for Game ID 2022020377.
# Loading cached data for Game ID 2022020378.
# Loading cached data for Game ID 2022020379.
# Loading cached data for Game ID 2022020380.
# Loading cached data for Game ID 2022020381.
# Loading cached data for Game ID 2022020382.
# Loading cached data for Game ID 2022020383.
# Loading cached data for Game ID 2022020384.
# Loading cached data for Game ID 2022020385.
# Loading cached data for Game ID 2022020386.
# Loading cached data for Game ID 2022020387.
# Loading cached data for Game ID 2022020388.
# Loading cached data for Game ID 2022020389.
# Loading cached data for Game ID 2022020390.
# Loading cached data for Game ID 2022020391.
# Loading cached data for Game ID 2022020392.
# Loading cached data for Game ID 2022020393.
# Loading cached data for Game ID 2022020394.
# Loading cached data for Game ID 2022020395.
# Loading cached data for Game ID 2022020396.
# Loading cached data for Game ID 2022020397.
# Loading cached data for Game ID 2022020398.
# Loading cached data for Game ID 2022020399.
# Loading cached data for Game ID 2022020400.
# Loading cached data for Game ID 2022020401.
# Loading cached data for Game ID 2022020402.
# Loading cached data for Game ID 2022020403.
# Loading cached data for Game ID 2022020404.
# Loading cached data for Game ID 2022020405.
# Loading cached data for Game ID 2022020406.
# Loading cached data for Game ID 2022020407.
# Loading cached data for Game ID 2022020408.
# Loading cached data for Game ID 2022020409.
# Loading cached data for Game ID 2022020410.
# Loading cached data for Game ID 2022020411.
# Loading cached data for Game ID 2022020412.
# Loading cached data for Game ID 2022020413.
# Loading cached data for Game ID 2022020414.
# Loading cached data for Game ID 2022020415.
# Loading cached data for Game ID 2022020416.
# Loading cached data for Game ID 2022020417.
# Loading cached data for Game ID 2022020418.
# Loading cached data for Game ID 2022020419.
# Loading cached data for Game ID 2022020420.
# Loading cached data for Game ID 2022020421.
# Loading cached data for Game ID 2022020422.
# Loading cached data for Game ID 2022020423.
# Loading cached data for Game ID 2022020424.
# Loading cached data for Game ID 2022020425.
# Loading cached data for Game ID 2022020426.
# Loading cached data for Game ID 2022020427.
# Loading cached data for Game ID 2022020428.
# Loading cached data for Game ID 2022020429.
# Loading cached data for Game ID 2022020430.
# Loading cached data for Game ID 2022020431.
# Loading cached data for Game ID 2022020432.
# Loading cached data for Game ID 2022020433.
# Loading cached data for Game ID 2022020434.
# Loading cached data for Game ID 2022020435.
# Loading cached data for Game ID 2022020436.
# Loading cached data for Game ID 2022020437.
# Loading cached data for Game ID 2022020438.
# Loading cached data for Game ID 2022020439.
# Loading cached data for Game ID 2022020440.
# Loading cached data for Game ID 2022020441.
# Loading cached data for Game ID 2022020442.
# Loading cached data for Game ID 2022020443.
# Loading cached data for Game ID 2022020444.
# Loading cached data for Game ID 2022020445.
# Loading cached data for Game ID 2022020446.
# Loading cached data for Game ID 2022020447.
# Loading cached data for Game ID 2022020448.
# Loading cached data for Game ID 2022020449.
# Loading cached data for Game ID 2022020450.
# Loading cached data for Game ID 2022020451.
# Loading cached data for Game ID 2022020452.
# Loading cached data for Game ID 2022020453.
# Loading cached data for Game ID 2022020454.
# Loading cached data for Game ID 2022020455.
# Loading cached data for Game ID 2022020456.
# Loading cached data for Game ID 2022020457.
# Loading cached data for Game ID 2022020458.
# Loading cached data for Game ID 2022020459.
# Loading cached data for Game ID 2022020460.
# Loading cached data for Game ID 2022020461.
# Loading cached data for Game ID 2022020462.
# Loading cached data for Game ID 2022020463.
# Loading cached data for Game ID 2022020464.
# Loading cached data for Game ID 2022020465.
# Loading cached data for Game ID 2022020466.
# Loading cached data for Game ID 2022020467.
# Loading cached data for Game ID 2022020468.
# Loading cached data for Game ID 2022020469.
# Loading cached data for Game ID 2022020470.
# Loading cached data for Game ID 2022020471.
# Loading cached data for Game ID 2022020472.
# Loading cached data for Game ID 2022020473.
# Loading cached data for Game ID 2022020474.
# Loading cached data for Game ID 2022020475.
# Loading cached data for Game ID 2022020476.
# Loading cached data for Game ID 2022020477.
# Loading cached data for Game ID 2022020478.
# Loading cached data for Game ID 2022020479.
# Loading cached data for Game ID 2022020480.
# Loading cached data for Game ID 2022020481.
# Loading cached data for Game ID 2022020482.
# Loading cached data for Game ID 2022020483.
# Loading cached data for Game ID 2022020484.
# Loading cached data for Game ID 2022020485.
# Loading cached data for Game ID 2022020486.
# Loading cached data for Game ID 2022020487.
# Loading cached data for Game ID 2022020488.
# Loading cached data for Game ID 2022020489.
# Loading cached data for Game ID 2022020490.
# Loading cached data for Game ID 2022020491.
# Loading cached data for Game ID 2022020492.
# Loading cached data for Game ID 2022020493.
# Loading cached data for Game ID 2022020494.
# Loading cached data for Game ID 2022020495.
# Loading cached data for Game ID 2022020496.
# Loading cached data for Game ID 2022020497.
# Loading cached data for Game ID 2022020498.
# Loading cached data for Game ID 2022020499.
# Loading cached data for Game ID 2022020500.
# Loading cached data for Game ID 2022020501.
# Loading cached data for Game ID 2022020502.
# Loading cached data for Game ID 2022020503.
# Loading cached data for Game ID 2022020504.
# Loading cached data for Game ID 2022020505.
# Loading cached data for Game ID 2022020506.
# Loading cached data for Game ID 2022020507.
# Loading cached data for Game ID 2022020508.
# Loading cached data for Game ID 2022020509.
# Loading cached data for Game ID 2022020510.
# Loading cached data for Game ID 2022020511.
# Loading cached data for Game ID 2022020512.
# Loading cached data for Game ID 2022020513.
# Loading cached data for Game ID 2022020514.
# Loading cached data for Game ID 2022020515.
# Loading cached data for Game ID 2022020516.
# Loading cached data for Game ID 2022020517.
# Loading cached data for Game ID 2022020518.
# Loading cached data for Game ID 2022020519.
# Loading cached data for Game ID 2022020520.
# Loading cached data for Game ID 2022020521.
# Loading cached data for Game ID 2022020522.
# Loading cached data for Game ID 2022020523.
# Loading cached data for Game ID 2022020524.
# Loading cached data for Game ID 2022020525.
# Loading cached data for Game ID 2022020526.
# Loading cached data for Game ID 2022020527.
# Loading cached data for Game ID 2022020528.
# Loading cached data for Game ID 2022020529.
# Loading cached data for Game ID 2022020530.
# Loading cached data for Game ID 2022020531.
# Loading cached data for Game ID 2022020532.
# Loading cached data for Game ID 2022020533.
# Loading cached data for Game ID 2022020534.
# Loading cached data for Game ID 2022020535.
# Loading cached data for Game ID 2022020536.
# Loading cached data for Game ID 2022020537.
# Loading cached data for Game ID 2022020538.
# Loading cached data for Game ID 2022020539.
# Loading cached data for Game ID 2022020540.
# Loading cached data for Game ID 2022020541.
# Loading cached data for Game ID 2022020542.
# Loading cached data for Game ID 2022020543.
# Loading cached data for Game ID 2022020544.
# Loading cached data for Game ID 2022020545.
# Loading cached data for Game ID 2022020546.
# Loading cached data for Game ID 2022020547.
# Loading cached data for Game ID 2022020548.
# Loading cached data for Game ID 2022020549.
# Loading cached data for Game ID 2022020550.
# Loading cached data for Game ID 2022020551.
# Loading cached data for Game ID 2022020552.
# Loading cached data for Game ID 2022020553.
# Loading cached data for Game ID 2022020554.
# Loading cached data for Game ID 2022020555.
# Loading cached data for Game ID 2022020556.
# Loading cached data for Game ID 2022020557.
# Loading cached data for Game ID 2022020558.
# Loading cached data for Game ID 2022020559.
# Loading cached data for Game ID 2022020560.
# Loading cached data for Game ID 2022020561.
# Loading cached data for Game ID 2022020562.
# Loading cached data for Game ID 2022020563.
# Loading cached data for Game ID 2022020564.
# Loading cached data for Game ID 2022020565.
# Loading cached data for Game ID 2022020566.
# Loading cached data for Game ID 2022020567.
# Loading cached data for Game ID 2022020568.
# Loading cached data for Game ID 2022020569.
# Loading cached data for Game ID 2022020570.
# Loading cached data for Game ID 2022020571.
# Loading cached data for Game ID 2022020572.
# Loading cached data for Game ID 2022020573.
# Loading cached data for Game ID 2022020574.
# Loading cached data for Game ID 2022020575.
# Loading cached data for Game ID 2022020576.
# Loading cached data for Game ID 2022020577.
# Loading cached data for Game ID 2022020578.
# Loading cached data for Game ID 2022020579.
# Loading cached data for Game ID 2022020580.
# Loading cached data for Game ID 2022020581.
# Loading cached data for Game ID 2022020582.
# Loading cached data for Game ID 2022020583.
# Loading cached data for Game ID 2022020584.
# Loading cached data for Game ID 2022020585.
# Loading cached data for Game ID 2022020586.
# Loading cached data for Game ID 2022020587.
# Loading cached data for Game ID 2022020588.
# Loading cached data for Game ID 2022020589.
# Loading cached data for Game ID 2022020590.
# Loading cached data for Game ID 2022020591.
# Loading cached data for Game ID 2022020592.
# Loading cached data for Game ID 2022020593.
# Loading cached data for Game ID 2022020594.
# Loading cached data for Game ID 2022020595.
# Loading cached data for Game ID 2022020596.
# Loading cached data for Game ID 2022020597.
# Loading cached data for Game ID 2022020598.
# Loading cached data for Game ID 2022020599.
# Loading cached data for Game ID 2022020600.
# Loading cached data for Game ID 2022020601.
# Loading cached data for Game ID 2022020602.
# Loading cached data for Game ID 2022020603.
# Loading cached data for Game ID 2022020604.
# Loading cached data for Game ID 2022020605.
# Loading cached data for Game ID 2022020606.
# Loading cached data for Game ID 2022020607.
# Loading cached data for Game ID 2022020608.
# Loading cached data for Game ID 2022020609.
# Loading cached data for Game ID 2022020610.
# Loading cached data for Game ID 2022020611.
# Loading cached data for Game ID 2022020612.
# Loading cached data for Game ID 2022020613.
# Loading cached data for Game ID 2022020614.
# Loading cached data for Game ID 2022020615.
# Loading cached data for Game ID 2022020616.
# Loading cached data for Game ID 2022020617.
# Loading cached data for Game ID 2022020618.
# Loading cached data for Game ID 2022020619.
# Loading cached data for Game ID 2022020620.
# Loading cached data for Game ID 2022020621.
# Loading cached data for Game ID 2022020622.
# Loading cached data for Game ID 2022020623.
# Loading cached data for Game ID 2022020624.
# Loading cached data for Game ID 2022020625.
# Loading cached data for Game ID 2022020626.
# Loading cached data for Game ID 2022020627.
# Loading cached data for Game ID 2022020628.
# Loading cached data for Game ID 2022020629.
# Loading cached data for Game ID 2022020630.
# Loading cached data for Game ID 2022020631.
# Loading cached data for Game ID 2022020632.
# Loading cached data for Game ID 2022020633.
# Loading cached data for Game ID 2022020634.
# Loading cached data for Game ID 2022020635.
# Loading cached data for Game ID 2022020636.
# Loading cached data for Game ID 2022020637.
# Loading cached data for Game ID 2022020638.
# Loading cached data for Game ID 2022020639.
# Loading cached data for Game ID 2022020640.
# Loading cached data for Game ID 2022020641.
# Loading cached data for Game ID 2022020642.
# Loading cached data for Game ID 2022020643.
# Loading cached data for Game ID 2022020644.
# Loading cached data for Game ID 2022020645.
# Loading cached data for Game ID 2022020646.
# Loading cached data for Game ID 2022020647.
# Loading cached data for Game ID 2022020648.
# Loading cached data for Game ID 2022020649.
# Loading cached data for Game ID 2022020650.
# Loading cached data for Game ID 2022020651.
# Loading cached data for Game ID 2022020652.
# Loading cached data for Game ID 2022020653.
# Loading cached data for Game ID 2022020654.
# Loading cached data for Game ID 2022020655.
# Loading cached data for Game ID 2022020656.
# Loading cached data for Game ID 2022020657.
# Loading cached data for Game ID 2022020658.
# Loading cached data for Game ID 2022020659.
# Loading cached data for Game ID 2022020660.
# Loading cached data for Game ID 2022020661.
# Loading cached data for Game ID 2022020662.
# Loading cached data for Game ID 2022020663.
# Loading cached data for Game ID 2022020664.
# Loading cached data for Game ID 2022020665.
# Loading cached data for Game ID 2022020666.
# Loading cached data for Game ID 2022020667.
# Loading cached data for Game ID 2022020668.
# Loading cached data for Game ID 2022020669.
# Loading cached data for Game ID 2022020670.
# Loading cached data for Game ID 2022020671.
# Loading cached data for Game ID 2022020672.
# Loading cached data for Game ID 2022020673.
# Loading cached data for Game ID 2022020674.
# Loading cached data for Game ID 2022020675.
# Loading cached data for Game ID 2022020676.
# Loading cached data for Game ID 2022020677.
# Loading cached data for Game ID 2022020678.
# Loading cached data for Game ID 2022020679.
# Loading cached data for Game ID 2022020680.
# Loading cached data for Game ID 2022020681.
# Loading cached data for Game ID 2022020682.
# Loading cached data for Game ID 2022020683.
# Loading cached data for Game ID 2022020684.
# Loading cached data for Game ID 2022020685.
# Loading cached data for Game ID 2022020686.
# Loading cached data for Game ID 2022020687.
# Loading cached data for Game ID 2022020688.
# Loading cached data for Game ID 2022020689.
# Loading cached data for Game ID 2022020690.
# Loading cached data for Game ID 2022020691.
# Loading cached data for Game ID 2022020692.
# Loading cached data for Game ID 2022020693.
# Loading cached data for Game ID 2022020694.
# Loading cached data for Game ID 2022020695.
# Loading cached data for Game ID 2022020696.
# Loading cached data for Game ID 2022020697.
# Loading cached data for Game ID 2022020698.
# Loading cached data for Game ID 2022020699.
# Loading cached data for Game ID 2022020700.
# Loading cached data for Game ID 2022020701.
# Loading cached data for Game ID 2022020702.
# Loading cached data for Game ID 2022020703.
# Loading cached data for Game ID 2022020704.
# Loading cached data for Game ID 2022020705.
# Loading cached data for Game ID 2022020706.
# Loading cached data for Game ID 2022020707.
# Loading cached data for Game ID 2022020708.
# Loading cached data for Game ID 2022020709.
# Loading cached data for Game ID 2022020710.
# Loading cached data for Game ID 2022020711.
# Loading cached data for Game ID 2022020712.
# Loading cached data for Game ID 2022020713.
# Loading cached data for Game ID 2022020714.
# Loading cached data for Game ID 2022020715.
# Loading cached data for Game ID 2022020716.
# Loading cached data for Game ID 2022020717.
# Loading cached data for Game ID 2022020718.
# Loading cached data for Game ID 2022020719.
# Loading cached data for Game ID 2022020720.
# Loading cached data for Game ID 2022020721.
# Loading cached data for Game ID 2022020722.
# Loading cached data for Game ID 2022020723.
# Loading cached data for Game ID 2022020724.
# Loading cached data for Game ID 2022020725.
# Loading cached data for Game ID 2022020726.
# Loading cached data for Game ID 2022020727.
# Loading cached data for Game ID 2022020728.
# Loading cached data for Game ID 2022020729.
# Loading cached data for Game ID 2022020730.
# Loading cached data for Game ID 2022020731.
# Loading cached data for Game ID 2022020732.
# Loading cached data for Game ID 2022020733.
# Loading cached data for Game ID 2022020734.
# Loading cached data for Game ID 2022020735.
# Loading cached data for Game ID 2022020736.
# Loading cached data for Game ID 2022020737.
# Loading cached data for Game ID 2022020738.
# Loading cached data for Game ID 2022020739.
# Loading cached data for Game ID 2022020740.
# Loading cached data for Game ID 2022020741.
# Loading cached data for Game ID 2022020742.
# Loading cached data for Game ID 2022020743.
# Loading cached data for Game ID 2022020744.
# Loading cached data for Game ID 2022020745.
# Loading cached data for Game ID 2022020746.
# Loading cached data for Game ID 2022020747.
# Loading cached data for Game ID 2022020748.
# Loading cached data for Game ID 2022020749.
# Loading cached data for Game ID 2022020750.
# Loading cached data for Game ID 2022020751.
# Loading cached data for Game ID 2022020752.
# Loading cached data for Game ID 2022020753.
# Loading cached data for Game ID 2022020754.
# Loading cached data for Game ID 2022020755.
# Loading cached data for Game ID 2022020756.
# Loading cached data for Game ID 2022020757.
# Loading cached data for Game ID 2022020758.
# Loading cached data for Game ID 2022020759.
# Loading cached data for Game ID 2022020760.
# Loading cached data for Game ID 2022020761.
# Loading cached data for Game ID 2022020762.
# Loading cached data for Game ID 2022020763.
# Loading cached data for Game ID 2022020764.
# Loading cached data for Game ID 2022020765.
# Loading cached data for Game ID 2022020766.
# Loading cached data for Game ID 2022020767.
# Loading cached data for Game ID 2022020768.
# Loading cached data for Game ID 2022020769.
# Loading cached data for Game ID 2022020770.
# Loading cached data for Game ID 2022020771.
# Loading cached data for Game ID 2022020772.
# Loading cached data for Game ID 2022020773.
# Loading cached data for Game ID 2022020774.
# Loading cached data for Game ID 2022020775.
# Loading cached data for Game ID 2022020776.
# Loading cached data for Game ID 2022020777.
# Loading cached data for Game ID 2022020778.
# Loading cached data for Game ID 2022020779.
# Loading cached data for Game ID 2022020780.
# Loading cached data for Game ID 2022020781.
# Loading cached data for Game ID 2022020782.
# Loading cached data for Game ID 2022020783.
# Loading cached data for Game ID 2022020784.
# Loading cached data for Game ID 2022020785.
# Loading cached data for Game ID 2022020786.
# Loading cached data for Game ID 2022020787.
# Loading cached data for Game ID 2022020788.
# Loading cached data for Game ID 2022020789.
# Loading cached data for Game ID 2022020790.
# Loading cached data for Game ID 2022020791.
# Loading cached data for Game ID 2022020792.
# Loading cached data for Game ID 2022020793.
# Loading cached data for Game ID 2022020794.
# Loading cached data for Game ID 2022020795.
# Loading cached data for Game ID 2022020796.
# Loading cached data for Game ID 2022020797.
# Loading cached data for Game ID 2022020798.
# Loading cached data for Game ID 2022020799.
# Loading cached data for Game ID 2022020800.
# Loading cached data for Game ID 2022020801.
# Loading cached data for Game ID 2022020802.
# Loading cached data for Game ID 2022020803.
# Loading cached data for Game ID 2022020804.
# Loading cached data for Game ID 2022020805.
# Loading cached data for Game ID 2022020806.
# Loading cached data for Game ID 2022020807.
# Loading cached data for Game ID 2022020808.
# Loading cached data for Game ID 2022020809.
# Loading cached data for Game ID 2022020810.
# Loading cached data for Game ID 2022020811.
# Loading cached data for Game ID 2022020812.
# Loading cached data for Game ID 2022020813.
# Loading cached data for Game ID 2022020814.
# Loading cached data for Game ID 2022020815.
# Loading cached data for Game ID 2022020816.
# Loading cached data for Game ID 2022020817.
# Loading cached data for Game ID 2022020818.
# Loading cached data for Game ID 2022020819.
# Loading cached data for Game ID 2022020820.
# Loading cached data for Game ID 2022020821.
# Loading cached data for Game ID 2022020822.
# Loading cached data for Game ID 2022020823.
# Loading cached data for Game ID 2022020824.
# Loading cached data for Game ID 2022020825.
# Loading cached data for Game ID 2022020826.
# Loading cached data for Game ID 2022020827.
# Loading cached data for Game ID 2022020828.
# Loading cached data for Game ID 2022020829.
# Loading cached data for Game ID 2022020830.
# Loading cached data for Game ID 2022020831.
# Loading cached data for Game ID 2022020832.
# Loading cached data for Game ID 2022020833.
# Loading cached data for Game ID 2022020834.
# Loading cached data for Game ID 2022020835.
# Loading cached data for Game ID 2022020836.
# Loading cached data for Game ID 2022020837.
# Loading cached data for Game ID 2022020838.
# Loading cached data for Game ID 2022020839.
# Loading cached data for Game ID 2022020840.
# Loading cached data for Game ID 2022020841.
# Loading cached data for Game ID 2022020842.
# Loading cached data for Game ID 2022020843.
# Loading cached data for Game ID 2022020844.
# Loading cached data for Game ID 2022020845.
# Loading cached data for Game ID 2022020846.
# Loading cached data for Game ID 2022020847.
# Loading cached data for Game ID 2022020848.
# Loading cached data for Game ID 2022020849.
# Loading cached data for Game ID 2022020850.
# Loading cached data for Game ID 2022020851.
# Loading cached data for Game ID 2022020852.
# Loading cached data for Game ID 2022020853.
# Loading cached data for Game ID 2022020854.
# Loading cached data for Game ID 2022020855.
# Loading cached data for Game ID 2022020856.
# Loading cached data for Game ID 2022020857.
# Loading cached data for Game ID 2022020858.
# Loading cached data for Game ID 2022020859.
# Loading cached data for Game ID 2022020860.
# Loading cached data for Game ID 2022020861.
# Loading cached data for Game ID 2022020862.
# Loading cached data for Game ID 2022020863.
# Loading cached data for Game ID 2022020864.
# Loading cached data for Game ID 2022020865.
# Loading cached data for Game ID 2022020866.
# Loading cached data for Game ID 2022020867.
# Loading cached data for Game ID 2022020868.
# Loading cached data for Game ID 2022020869.
# Loading cached data for Game ID 2022020870.
# Loading cached data for Game ID 2022020871.
# Loading cached data for Game ID 2022020872.
# Loading cached data for Game ID 2022020873.
# Loading cached data for Game ID 2022020874.
# Loading cached data for Game ID 2022020875.
# Loading cached data for Game ID 2022020876.
# Loading cached data for Game ID 2022020877.
# Loading cached data for Game ID 2022020878.
# Loading cached data for Game ID 2022020879.
# Loading cached data for Game ID 2022020880.
# Loading cached data for Game ID 2022020881.
# Loading cached data for Game ID 2022020882.
# Loading cached data for Game ID 2022020883.
# Loading cached data for Game ID 2022020884.
# Loading cached data for Game ID 2022020885.
# Loading cached data for Game ID 2022020886.
# Loading cached data for Game ID 2022020887.
# Loading cached data for Game ID 2022020888.
# Loading cached data for Game ID 2022020889.
# Loading cached data for Game ID 2022020890.
# Loading cached data for Game ID 2022020891.
# Loading cached data for Game ID 2022020892.
# Loading cached data for Game ID 2022020893.
# Loading cached data for Game ID 2022020894.
# Loading cached data for Game ID 2022020895.
# Loading cached data for Game ID 2022020896.
# Loading cached data for Game ID 2022020897.
# Loading cached data for Game ID 2022020898.
# Loading cached data for Game ID 2022020899.
# Loading cached data for Game ID 2022020900.
# Loading cached data for Game ID 2022020901.
# Loading cached data for Game ID 2022020902.
# Loading cached data for Game ID 2022020903.
# Loading cached data for Game ID 2022020904.
# Loading cached data for Game ID 2022020905.
# Loading cached data for Game ID 2022020906.
# Loading cached data for Game ID 2022020907.
# Loading cached data for Game ID 2022020908.
# Loading cached data for Game ID 2022020909.
# Loading cached data for Game ID 2022020910.
# Loading cached data for Game ID 2022020911.
# Loading cached data for Game ID 2022020912.
# Loading cached data for Game ID 2022020913.
# Loading cached data for Game ID 2022020914.
# Loading cached data for Game ID 2022020915.
# Loading cached data for Game ID 2022020916.
# Loading cached data for Game ID 2022020917.
# Loading cached data for Game ID 2022020918.
# Loading cached data for Game ID 2022020919.
# Loading cached data for Game ID 2022020920.
# Loading cached data for Game ID 2022020921.
# Loading cached data for Game ID 2022020922.
# Loading cached data for Game ID 2022020923.
# Loading cached data for Game ID 2022020924.
# Loading cached data for Game ID 2022020925.
# Loading cached data for Game ID 2022020926.
# Loading cached data for Game ID 2022020927.
# Loading cached data for Game ID 2022020928.
# Loading cached data for Game ID 2022020929.
# Loading cached data for Game ID 2022020930.
# Loading cached data for Game ID 2022020931.
# Loading cached data for Game ID 2022020932.
# Loading cached data for Game ID 2022020933.
# Loading cached data for Game ID 2022020934.
# Loading cached data for Game ID 2022020935.
# Loading cached data for Game ID 2022020936.
# Loading cached data for Game ID 2022020937.
# Loading cached data for Game ID 2022020938.
# Loading cached data for Game ID 2022020939.
# Loading cached data for Game ID 2022020940.
# Loading cached data for Game ID 2022020941.
# Loading cached data for Game ID 2022020942.
# Loading cached data for Game ID 2022020943.
# Loading cached data for Game ID 2022020944.
# Loading cached data for Game ID 2022020945.
# Loading cached data for Game ID 2022020946.
# Loading cached data for Game ID 2022020947.
# Loading cached data for Game ID 2022020948.
# Loading cached data for Game ID 2022020949.
# Loading cached data for Game ID 2022020950.
# Loading cached data for Game ID 2022020951.
# Loading cached data for Game ID 2022020952.
# Loading cached data for Game ID 2022020953.
# Loading cached data for Game ID 2022020954.
# Loading cached data for Game ID 2022020955.
# Loading cached data for Game ID 2022020956.
# Loading cached data for Game ID 2022020957.
# Loading cached data for Game ID 2022020958.
# Loading cached data for Game ID 2022020959.
# Loading cached data for Game ID 2022020960.
# Loading cached data for Game ID 2022020961.
# Loading cached data for Game ID 2022020962.
# Loading cached data for Game ID 2022020963.
# Loading cached data for Game ID 2022020964.
# Loading cached data for Game ID 2022020965.
# Loading cached data for Game ID 2022020966.
# Loading cached data for Game ID 2022020967.
# Loading cached data for Game ID 2022020968.
# Loading cached data for Game ID 2022020969.
# Loading cached data for Game ID 2022020970.
# Loading cached data for Game ID 2022020971.
# Loading cached data for Game ID 2022020972.
# Loading cached data for Game ID 2022020973.
# Loading cached data for Game ID 2022020974.
# Loading cached data for Game ID 2022020975.
# Loading cached data for Game ID 2022020976.
# Loading cached data for Game ID 2022020977.
# Loading cached data for Game ID 2022020978.
# Loading cached data for Game ID 2022020979.
# Loading cached data for Game ID 2022020980.
# Loading cached data for Game ID 2022020981.
# Loading cached data for Game ID 2022020982.
# Loading cached data for Game ID 2022020983.
# Loading cached data for Game ID 2022020984.
# Loading cached data for Game ID 2022020985.
# Loading cached data for Game ID 2022020986.
# Loading cached data for Game ID 2022020987.
# Loading cached data for Game ID 2022020988.
# Loading cached data for Game ID 2022020989.
# Loading cached data for Game ID 2022020990.
# Loading cached data for Game ID 2022020991.
# Loading cached data for Game ID 2022020992.
# Loading cached data for Game ID 2022020993.
# Loading cached data for Game ID 2022020994.
# Loading cached data for Game ID 2022020995.
# Loading cached data for Game ID 2022020996.
# Loading cached data for Game ID 2022020997.
# Loading cached data for Game ID 2022020998.
# Loading cached data for Game ID 2022020999.
# Loading cached data for Game ID 2022021000.
# Loading cached data for Game ID 2022021001.
# Loading cached data for Game ID 2022021002.
# Loading cached data for Game ID 2022021003.
# Loading cached data for Game ID 2022021004.
# Loading cached data for Game ID 2022021005.
# Loading cached data for Game ID 2022021006.
# Loading cached data for Game ID 2022021007.
# Loading cached data for Game ID 2022021008.
# Loading cached data for Game ID 2022021009.
# Loading cached data for Game ID 2022021010.
# Loading cached data for Game ID 2022021011.
# Loading cached data for Game ID 2022021012.
# Loading cached data for Game ID 2022021013.
# Loading cached data for Game ID 2022021014.
# Loading cached data for Game ID 2022021015.
# Loading cached data for Game ID 2022021016.
# Loading cached data for Game ID 2022021017.
# Loading cached data for Game ID 2022021018.
# Loading cached data for Game ID 2022021019.
# Loading cached data for Game ID 2022021020.
# Loading cached data for Game ID 2022021021.
# Loading cached data for Game ID 2022021022.
# Loading cached data for Game ID 2022021023.
# Loading cached data for Game ID 2022021024.
# Loading cached data for Game ID 2022021025.
# Loading cached data for Game ID 2022021026.
# Loading cached data for Game ID 2022021027.
# Loading cached data for Game ID 2022021028.
# Loading cached data for Game ID 2022021029.
# Loading cached data for Game ID 2022021030.
# Loading cached data for Game ID 2022021031.
# Loading cached data for Game ID 2022021032.
# Loading cached data for Game ID 2022021033.
# Loading cached data for Game ID 2022021034.
# Loading cached data for Game ID 2022021035.
# Loading cached data for Game ID 2022021036.
# Loading cached data for Game ID 2022021037.
# Loading cached data for Game ID 2022021038.
# Loading cached data for Game ID 2022021039.
# Loading cached data for Game ID 2022021040.
# Loading cached data for Game ID 2022021041.
# Loading cached data for Game ID 2022021042.
# Loading cached data for Game ID 2022021043.
# Loading cached data for Game ID 2022021044.
# Loading cached data for Game ID 2022021045.
# Loading cached data for Game ID 2022021046.
# Loading cached data for Game ID 2022021047.
# Loading cached data for Game ID 2022021048.
# Loading cached data for Game ID 2022021049.
# Loading cached data for Game ID 2022021050.
# Loading cached data for Game ID 2022021051.
# Loading cached data for Game ID 2022021052.
# Loading cached data for Game ID 2022021053.
# Loading cached data for Game ID 2022021054.
# Loading cached data for Game ID 2022021055.
# Loading cached data for Game ID 2022021056.
# Loading cached data for Game ID 2022021057.
# Loading cached data for Game ID 2022021058.
# Loading cached data for Game ID 2022021059.
# Loading cached data for Game ID 2022021060.
# Loading cached data for Game ID 2022021061.
# Loading cached data for Game ID 2022021062.
# Loading cached data for Game ID 2022021063.
# Loading cached data for Game ID 2022021064.
# Loading cached data for Game ID 2022021065.
# Loading cached data for Game ID 2022021066.
# Loading cached data for Game ID 2022021067.
# Loading cached data for Game ID 2022021068.
# Loading cached data for Game ID 2022021069.
# Loading cached data for Game ID 2022021070.
# Loading cached data for Game ID 2022021071.
# Loading cached data for Game ID 2022021072.
# Loading cached data for Game ID 2022021073.
# Loading cached data for Game ID 2022021074.
# Loading cached data for Game ID 2022021075.
# Loading cached data for Game ID 2022021076.
# Loading cached data for Game ID 2022021077.
# Loading cached data for Game ID 2022021078.
# Loading cached data for Game ID 2022021079.
# Loading cached data for Game ID 2022021080.
# Loading cached data for Game ID 2022021081.
# Loading cached data for Game ID 2022021082.
# Loading cached data for Game ID 2022021083.
# Loading cached data for Game ID 2022021084.
# Loading cached data for Game ID 2022021085.
# Loading cached data for Game ID 2022021086.
# Loading cached data for Game ID 2022021087.
# Loading cached data for Game ID 2022021088.
# Loading cached data for Game ID 2022021089.
# Loading cached data for Game ID 2022021090.
# Loading cached data for Game ID 2022021091.
# Loading cached data for Game ID 2022021092.
# Loading cached data for Game ID 2022021093.
# Loading cached data for Game ID 2022021094.
# Loading cached data for Game ID 2022021095.
# Loading cached data for Game ID 2022021096.
# Loading cached data for Game ID 2022021097.
# Loading cached data for Game ID 2022021098.
# Loading cached data for Game ID 2022021099.
# Loading cached data for Game ID 2022021100.
# Loading cached data for Game ID 2022021101.
# Loading cached data for Game ID 2022021102.
# Loading cached data for Game ID 2022021103.
# Loading cached data for Game ID 2022021104.
# Loading cached data for Game ID 2022021105.
# Loading cached data for Game ID 2022021106.
# Loading cached data for Game ID 2022021107.
# Loading cached data for Game ID 2022021108.
# Loading cached data for Game ID 2022021109.
# Loading cached data for Game ID 2022021110.
# Loading cached data for Game ID 2022021111.
# Loading cached data for Game ID 2022021112.
# Loading cached data for Game ID 2022021113.
# Loading cached data for Game ID 2022021114.
# Loading cached data for Game ID 2022021115.
# Loading cached data for Game ID 2022021116.
# Loading cached data for Game ID 2022021117.
# Loading cached data for Game ID 2022021118.
# Loading cached data for Game ID 2022021119.
# Loading cached data for Game ID 2022021120.
# Loading cached data for Game ID 2022021121.
# Loading cached data for Game ID 2022021122.
# Loading cached data for Game ID 2022021123.
# Loading cached data for Game ID 2022021124.
# Loading cached data for Game ID 2022021125.
# Loading cached data for Game ID 2022021126.
# Loading cached data for Game ID 2022021127.
# Loading cached data for Game ID 2022021128.
# Loading cached data for Game ID 2022021129.
# Loading cached data for Game ID 2022021130.
# Loading cached data for Game ID 2022021131.
# Loading cached data for Game ID 2022021132.
# Loading cached data for Game ID 2022021133.
# Loading cached data for Game ID 2022021134.
# Loading cached data for Game ID 2022021135.
# Loading cached data for Game ID 2022021136.
# Loading cached data for Game ID 2022021137.
# Loading cached data for Game ID 2022021138.
# Loading cached data for Game ID 2022021139.
# Loading cached data for Game ID 2022021140.
# Loading cached data for Game ID 2022021141.
# Loading cached data for Game ID 2022021142.
# Loading cached data for Game ID 2022021143.
# Loading cached data for Game ID 2022021144.
# Loading cached data for Game ID 2022021145.
# Loading cached data for Game ID 2022021146.
# Loading cached data for Game ID 2022021147.
# Loading cached data for Game ID 2022021148.
# Loading cached data for Game ID 2022021149.
# Loading cached data for Game ID 2022021150.
# Loading cached data for Game ID 2022021151.
# Loading cached data for Game ID 2022021152.
# Loading cached data for Game ID 2022021153.
# Loading cached data for Game ID 2022021154.
# Loading cached data for Game ID 2022021155.
# Loading cached data for Game ID 2022021156.
# Loading cached data for Game ID 2022021157.
# Loading cached data for Game ID 2022021158.
# Loading cached data for Game ID 2022021159.
# Loading cached data for Game ID 2022021160.
# Loading cached data for Game ID 2022021161.
# Loading cached data for Game ID 2022021162.
# Loading cached data for Game ID 2022021163.
# Loading cached data for Game ID 2022021164.
# Loading cached data for Game ID 2022021165.
# Loading cached data for Game ID 2022021166.
# Loading cached data for Game ID 2022021167.
# Loading cached data for Game ID 2022021168.
# Loading cached data for Game ID 2022021169.
# Loading cached data for Game ID 2022021170.
# Loading cached data for Game ID 2022021171.
# Loading cached data for Game ID 2022021172.
# Loading cached data for Game ID 2022021173.
# Loading cached data for Game ID 2022021174.
# Loading cached data for Game ID 2022021175.
# Loading cached data for Game ID 2022021176.
# Loading cached data for Game ID 2022021177.
# Loading cached data for Game ID 2022021178.
# Loading cached data for Game ID 2022021179.
# Loading cached data for Game ID 2022021180.
# Loading cached data for Game ID 2022021181.
# Loading cached data for Game ID 2022021182.
# Loading cached data for Game ID 2022021183.
# Loading cached data for Game ID 2022021184.
# Loading cached data for Game ID 2022021185.
# Loading cached data for Game ID 2022021186.
# Loading cached data for Game ID 2022021187.
# Loading cached data for Game ID 2022021188.
# Loading cached data for Game ID 2022021189.
# Loading cached data for Game ID 2022021190.
# Loading cached data for Game ID 2022021191.
# Loading cached data for Game ID 2022021192.
# Loading cached data for Game ID 2022021193.
# Loading cached data for Game ID 2022021194.
# Loading cached data for Game ID 2022021195.
# Loading cached data for Game ID 2022021196.
# Loading cached data for Game ID 2022021197.
# Loading cached data for Game ID 2022021198.
# Loading cached data for Game ID 2022021199.
# Loading cached data for Game ID 2022021200.
# Loading cached data for Game ID 2022021201.
# Loading cached data for Game ID 2022021202.
# Loading cached data for Game ID 2022021203.
# Loading cached data for Game ID 2022021204.
# Loading cached data for Game ID 2022021205.
# Loading cached data for Game ID 2022021206.
# Loading cached data for Game ID 2022021207.
# Loading cached data for Game ID 2022021208.
# Loading cached data for Game ID 2022021209.
# Loading cached data for Game ID 2022021210.
# Loading cached data for Game ID 2022021211.
# Loading cached data for Game ID 2022021212.
# Loading cached data for Game ID 2022021213.
# Loading cached data for Game ID 2022021214.
# Loading cached data for Game ID 2022021215.
# Loading cached data for Game ID 2022021216.
# Loading cached data for Game ID 2022021217.
# Loading cached data for Game ID 2022021218.
# Loading cached data for Game ID 2022021219.
# Loading cached data for Game ID 2022021220.
# Loading cached data for Game ID 2022021221.
# Loading cached data for Game ID 2022021222.
# Loading cached data for Game ID 2022021223.
# Loading cached data for Game ID 2022021224.
# Loading cached data for Game ID 2022021225.
# Loading cached data for Game ID 2022021226.
# Loading cached data for Game ID 2022021227.
# Loading cached data for Game ID 2022021228.
# Loading cached data for Game ID 2022021229.
# Loading cached data for Game ID 2022021230.
# Loading cached data for Game ID 2022021231.
# Loading cached data for Game ID 2022021232.
# Loading cached data for Game ID 2022021233.
# Loading cached data for Game ID 2022021234.
# Loading cached data for Game ID 2022021235.
# Loading cached data for Game ID 2022021236.
# Loading cached data for Game ID 2022021237.
# Loading cached data for Game ID 2022021238.
# Loading cached data for Game ID 2022021239.
# Loading cached data for Game ID 2022021240.
# Loading cached data for Game ID 2022021241.
# Loading cached data for Game ID 2022021242.
# Loading cached data for Game ID 2022021243.
# Loading cached data for Game ID 2022021244.
# Loading cached data for Game ID 2022021245.
# Loading cached data for Game ID 2022021246.
# Loading cached data for Game ID 2022021247.
# Loading cached data for Game ID 2022021248.
# Loading cached data for Game ID 2022021249.
# Loading cached data for Game ID 2022021250.
# Loading cached data for Game ID 2022021251.
# Loading cached data for Game ID 2022021252.
# Loading cached data for Game ID 2022021253.
# Loading cached data for Game ID 2022021254.
# Loading cached data for Game ID 2022021255.
# Loading cached data for Game ID 2022021256.
# Loading cached data for Game ID 2022021257.
# Loading cached data for Game ID 2022021258.
# Loading cached data for Game ID 2022021259.
# Loading cached data for Game ID 2022021260.
# Loading cached data for Game ID 2022021261.
# Loading cached data for Game ID 2022021262.
# Loading cached data for Game ID 2022021263.
# Loading cached data for Game ID 2022021264.
# Loading cached data for Game ID 2022021265.
# Loading cached data for Game ID 2022021266.
# Loading cached data for Game ID 2022021267.
# Loading cached data for Game ID 2022021268.
# Loading cached data for Game ID 2022021269.
# Loading cached data for Game ID 2022021270.
# Loading cached data for Game ID 2022021271.
# Loading cached data for Game ID 2022021272.
# Loading cached data for Game ID 2022021273.
# Loading cached data for Game ID 2022021274.
# Loading cached data for Game ID 2022021275.
# Loading cached data for Game ID 2022021276.
# Loading cached data for Game ID 2022021277.
# Loading cached data for Game ID 2022021278.
# Loading cached data for Game ID 2022021279.
# Loading cached data for Game ID 2022021280.
# Loading cached data for Game ID 2022021281.
# Loading cached data for Game ID 2022021282.
# Loading cached data for Game ID 2022021283.
# Loading cached data for Game ID 2022021284.
# Loading cached data for Game ID 2022021285.
# Loading cached data for Game ID 2022021286.
# Loading cached data for Game ID 2022021287.
# Loading cached data for Game ID 2022021288.
# Loading cached data for Game ID 2022021289.
# Loading cached data for Game ID 2022021290.
# Loading cached data for Game ID 2022021291.
# Loading cached data for Game ID 2022021292.
# Loading cached data for Game ID 2022021293.
# Loading cached data for Game ID 2022021294.
# Loading cached data for Game ID 2022021295.
# Loading cached data for Game ID 2022021296.
# Loading cached data for Game ID 2022021297.
# Loading cached data for Game ID 2022021298.
# Loading cached data for Game ID 2022021299.
# Loading cached data for Game ID 2022021300.
#
# Downloading playoff data for 2022-2023...
# Fetching data for Game ID 2022030001...
# Game ID 2022030001 not found (404). Skipping.
#
# Downloading regular season data for 2023-2024...
# Loading cached data for Game ID 2023020001.
# ...
# Fetching data for Game ID 2024021153...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021153.json
# Fetching data for Game ID 2024021154...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021154.json
# Fetching data for Game ID 2024021155...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021155.json
# Fetching data for Game ID 2024021156...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021156.json
# Fetching data for Game ID 2024021157...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021157.json
# Fetching data for Game ID 2024021158...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021158.json
# Fetching data for Game ID 2024021159...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021159.json
# Fetching data for Game ID 2024021160...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021160.json
# Fetching data for Game ID 2024021161...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021161.json
# Fetching data for Game ID 2024021162...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021162.json
# Fetching data for Game ID 2024021163...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021163.json
# Fetching data for Game ID 2024021164...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021164.json
# Fetching data for Game ID 2024021165...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021165.json
# Fetching data for Game ID 2024021166...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021166.json
# Fetching data for Game ID 2024021167...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021167.json
# Fetching data for Game ID 2024021168...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021168.json
# Fetching data for Game ID 2024021169...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021169.json
# Fetching data for Game ID 2024021170...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021170.json
# Fetching data for Game ID 2024021171...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021171.json
# Fetching data for Game ID 2024021172...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021172.json
# Fetching data for Game ID 2024021173...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021173.json
# Fetching data for Game ID 2024021174...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021174.json
# Fetching data for Game ID 2024021175...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021175.json
# Fetching data for Game ID 2024021176...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021176.json
# Fetching data for Game ID 2024021177...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021177.json
# Fetching data for Game ID 2024021178...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021178.json
# Fetching data for Game ID 2024021179...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021179.json
# Fetching data for Game ID 2024021180...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021180.json
# Fetching data for Game ID 2024021181...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021181.json
# Fetching data for Game ID 2024021182...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021182.json
# Fetching data for Game ID 2024021183...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021183.json
# Fetching data for Game ID 2024021184...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021184.json
# Fetching data for Game ID 2024021185...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021185.json
# Fetching data for Game ID 2024021186...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021186.json
# Fetching data for Game ID 2024021187...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021187.json
# Fetching data for Game ID 2024021188...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021188.json
# Fetching data for Game ID 2024021189...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021189.json
# Fetching data for Game ID 2024021190...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021190.json
# Fetching data for Game ID 2024021191...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021191.json
# Fetching data for Game ID 2024021192...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021192.json
# Fetching data for Game ID 2024021193...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021193.json
# Fetching data for Game ID 2024021194...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021194.json
# Fetching data for Game ID 2024021195...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021195.json
# Fetching data for Game ID 2024021196...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021196.json
# Fetching data for Game ID 2024021197...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021197.json
# Fetching data for Game ID 2024021198...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021198.json
# Fetching data for Game ID 2024021199...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021199.json
# Fetching data for Game ID 2024021200...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021200.json
# Fetching data for Game ID 2024021201...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021201.json
# Fetching data for Game ID 2024021202...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021202.json
# Fetching data for Game ID 2024021203...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021203.json
# Fetching data for Game ID 2024021204...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021204.json
# Fetching data for Game ID 2024021205...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021205.json
# Fetching data for Game ID 2024021206...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021206.json
# Fetching data for Game ID 2024021207...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021207.json
# Fetching data for Game ID 2024021208...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021208.json
# Fetching data for Game ID 2024021209...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021209.json
# Fetching data for Game ID 2024021210...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021210.json
# Fetching data for Game ID 2024021211...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021211.json
# Fetching data for Game ID 2024021212...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021212.json
# Fetching data for Game ID 2024021213...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021213.json
# Fetching data for Game ID 2024021214...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021214.json
# Fetching data for Game ID 2024021215...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021215.json
# Fetching data for Game ID 2024021216...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021216.json
# Fetching data for Game ID 2024021217...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021217.json
# Fetching data for Game ID 2024021218...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021218.json
# Fetching data for Game ID 2024021219...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021219.json
# Fetching data for Game ID 2024021220...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021220.json
# Fetching data for Game ID 2024021221...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021221.json
# Fetching data for Game ID 2024021222...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021222.json
# Fetching data for Game ID 2024021223...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021223.json
# Fetching data for Game ID 2024021224...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021224.json
# Fetching data for Game ID 2024021225...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021225.json
# Fetching data for Game ID 2024021226...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021226.json
# Fetching data for Game ID 2024021227...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021227.json
# Fetching data for Game ID 2024021228...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021228.json
# Fetching data for Game ID 2024021229...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021229.json
# Fetching data for Game ID 2024021230...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021230.json
# Fetching data for Game ID 2024021231...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021231.json
# Fetching data for Game ID 2024021232...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021232.json
# Fetching data for Game ID 2024021233...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021233.json
# Fetching data for Game ID 2024021234...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021234.json
# Fetching data for Game ID 2024021235...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021235.json
# Fetching data for Game ID 2024021236...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021236.json
# Fetching data for Game ID 2024021237...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021237.json
# Fetching data for Game ID 2024021238...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021238.json
# Fetching data for Game ID 2024021239...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021239.json
# Fetching data for Game ID 2024021240...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021240.json
# Fetching data for Game ID 2024021241...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021241.json
# Fetching data for Game ID 2024021242...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021242.json
# Fetching data for Game ID 2024021243...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021243.json
# Fetching data for Game ID 2024021244...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021244.json
# Fetching data for Game ID 2024021245...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021245.json
# Fetching data for Game ID 2024021246...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021246.json
# Fetching data for Game ID 2024021247...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021247.json
# Fetching data for Game ID 2024021248...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021248.json
# Fetching data for Game ID 2024021249...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021249.json
# Fetching data for Game ID 2024021250...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021250.json
# Fetching data for Game ID 2024021251...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021251.json
# Fetching data for Game ID 2024021252...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021252.json
# Fetching data for Game ID 2024021253...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021253.json
# Fetching data for Game ID 2024021254...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021254.json
# Fetching data for Game ID 2024021255...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021255.json
# Fetching data for Game ID 2024021256...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021256.json
# Fetching data for Game ID 2024021257...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021257.json
# Fetching data for Game ID 2024021258...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021258.json
# Fetching data for Game ID 2024021259...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021259.json
# Fetching data for Game ID 2024021260...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021260.json
# Fetching data for Game ID 2024021261...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021261.json
# Fetching data for Game ID 2024021262...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021262.json
# Fetching data for Game ID 2024021263...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021263.json
# Fetching data for Game ID 2024021264...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021264.json
# Fetching data for Game ID 2024021265...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021265.json
# Fetching data for Game ID 2024021266...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021266.json
# Fetching data for Game ID 2024021267...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021267.json
# Fetching data for Game ID 2024021268...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021268.json
# Fetching data for Game ID 2024021269...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021269.json
# Fetching data for Game ID 2024021270...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021270.json
# Fetching data for Game ID 2024021271...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021271.json
# Fetching data for Game ID 2024021272...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021272.json
# Fetching data for Game ID 2024021273...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021273.json
# Fetching data for Game ID 2024021274...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021274.json
# Fetching data for Game ID 2024021275...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021275.json
# Fetching data for Game ID 2024021276...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021276.json
# Fetching data for Game ID 2024021277...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021277.json
# Fetching data for Game ID 2024021278...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021278.json
# Fetching data for Game ID 2024021279...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021279.json
# Fetching data for Game ID 2024021280...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021280.json
# Fetching data for Game ID 2024021281...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021281.json
# Fetching data for Game ID 2024021282...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021282.json
# Fetching data for Game ID 2024021283...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021283.json
# Fetching data for Game ID 2024021284...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021284.json
# Fetching data for Game ID 2024021285...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021285.json
# Fetching data for Game ID 2024021286...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021286.json
# Fetching data for Game ID 2024021287...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021287.json
# Fetching data for Game ID 2024021288...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021288.json
# Fetching data for Game ID 2024021289...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021289.json
# Fetching data for Game ID 2024021290...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021290.json
# Fetching data for Game ID 2024021291...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021291.json
# Fetching data for Game ID 2024021292...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021292.json
# Fetching data for Game ID 2024021293...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021293.json
# Fetching data for Game ID 2024021294...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021294.json
# Fetching data for Game ID 2024021295...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021295.json
# Fetching data for Game ID 2024021296...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021296.json
# Fetching data for Game ID 2024021297...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021297.json
# Fetching data for Game ID 2024021298...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021298.json
# Fetching data for Game ID 2024021299...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021299.json
# Fetching data for Game ID 2024021300...
# Data saved to /content/drive/MyDrive/NHL_Datas/raw/2024021300.json
#
# Downloading playoff data for 2024-2025...
# Fetching data for Game ID 2024030001...
# Game ID 2024030001 not found (404). Skipping.

# %%
#  print thethe json file for Game ID 2024021300

from google.colab import drive
import os
import requests
import json

# Mount Google Drive
drive.mount('/content/drive')


# Cache directory inside Google Drive
CACHE_DIR = "/content/drive/MyDrive/NHL_Datas/raw"

def print_json_content(season, game_type, game_number, cache_dir=CACHE_DIR):
  """
  Prints the content of a JSON file.
  """
  game_id = f"{season}{game_type}{game_number}"
  cache_file = os.path.join(cache_dir, f"{game_id}.json")

  if os.path.exists(cache_file):
    print(f"Printing the content inside the json file Fetching data for Game ID {game_id}")
    with open(cache_file, 'r') as f:
      try:
        data = json.load(f)
        print(json.dumps(data, indent=2))  # Print with indentation for better readability
      except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
  else:
    print(f"File not found: {cache_file}")



# Example: Print the content of the JSON file for game ID 2024021300
print_json_content(2024, "02", "1300")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Printing the content inside the json file Fetching data for Game ID 2024021300
# {
#   "id": 2024021300,
#   "season": 20242025,
#   "gameType": 2,
#   "limitedScoring": false,
#   "gameDate": "2025-04-15",
#   "venue": {
#     "default": "Climate Pledge Arena"
#   },
#   "venueLocation": {
#     "default": "Seattle"
#   },
#   "startTimeUTC": "2025-04-16T02:30:00Z",
#   "easternUTCOffset": "-04:00",
#   "venueUTCOffset": "-07:00",
#   "tvBroadcasts": [
#     {
#       "id": 309,
#       "market": "N",
#       "countryCode": "US",
#       "network": "ESPN",
#       "sequenceNumber": 2
#     },
#     {
#       "id": 283,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "SN360",
#       "sequenceNumber": 103
#     }
#   ],
#   "gameState": "FUT",
#   "gameScheduleState": "OK",
#   "awayTeam": {
#     "id": 26,
#     "name": {
#       "default": "Kings"
#     },
#     "abbrev": "LAK",
#     "score": 0,
#     "logo": "https://assets.nhle.com/logos/nhl/svg/LAK_light.svg",
#     "darkLogo": "https://assets.nhle.com/logos/nhl/svg/LAK_dark.svg",
#     "placeName": {
#       "default": "Los Angeles"
#     },
#     "placeNameWithPreposition": {
#       "default": "Los Angeles",
#       "fr": "de Los Angeles"
#     }
#   },
#   "homeTeam": {
#     "id": 55,
#     "name": {
#       "default": "Kraken"
#     },
#     "abbrev": "SEA",
#     "score": 0,
#     "logo": "https://assets.nhle.com/logos/nhl/svg/SEA_light.svg",
#     "darkLogo": "https://assets.nhle.com/logos/nhl/svg/SEA_dark.svg",
#     "placeName": {
#       "default": "Seattle"
#     },
#     "placeNameWithPreposition": {
#       "default": "Seattle",
#       "fr": "de Seattle"
#     }
#   },
#   "shootoutInUse": true,
#   "otInUse": true,
#   "clock": {
#     "timeRemaining": "20:00",
#     "secondsRemaining": 1200,
#     "running": false,
#     "inIntermission": false
#   },
#   "displayPeriod": 1,
#   "maxPeriods": 5,
#   "plays": [],
#   "rosterSpots": [],
#   "regPeriods": 3
# }
